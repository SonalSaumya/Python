# %%
import numpy as np
import pandas as pd
from plotnine import ggplot, aes, geom_point, labs, geom_line, geom_bar

# %%
df = pd.read_csv('FIFA17_official_data.csv')

# %%
df.head()
# Out:
#        ID            Name  Age  \
# 0  176580       L. Suárez   29
# 1  178518   R. Nainggolan   28
# 2  181872        A. Vidal   29
# 3  197445        D. Alaba   24
# 4  195864        P. Pogba   23
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2  https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3  https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4  https://cdn.sofifa.com/players/195/864/17_60.png      France
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       92         92       FC Barcelona
# 1  https://cdn.sofifa.com/flags/be.png       86         86               Roma
# 2  https://cdn.sofifa.com/flags/cl.png       87         87  FC Bayern München
# ...

# %%
df['Name'].dropna()
# Out:
# 0             L. Suárez
# 1         R. Nainggolan
# 2              A. Vidal
# 3              D. Alaba
# 4              P. Pogba
#               ...
# 17555          C. Addai
# 17556       R. Kamiyama
# 17557           B. Gaye
# 17558     K. Olifirenko
# 17559         A. Kelsey
# Name: Name, Length: 17560, dtype: object

# %%
df['Overall'].dropna()
# Out:
# 0        92
# 1        86
# 2        87
# 3        86
# 4        88
#          ..
# 17555    54
# 17556    57
# 17557    53
# 17558    50
# 17559    46
# Name: Overall, Length: 17560, dtype: int64

# %%
df['Name'].drop_duplicates()
# Out:
# 0             L. Suárez
# 1         R. Nainggolan
# 2              A. Vidal
# 3              D. Alaba
# 4              P. Pogba
#               ...
# 17555          C. Addai
# 17556       R. Kamiyama
# 17557           B. Gaye
# 17558     K. Olifirenko
# 17559         A. Kelsey
# Name: Name, Length: 16596, dtype: object

# %%
df.sort_values(by=['Overall'],ascending=False)
# Out:
#            ID                Name  Age  \
# 9       20801   Cristiano Ronaldo   31
# 58     158023            L. Messi   29
# 0      176580           L. Suárez   29
# 12372  167495            M. Neuer   30
# 168    190871              Neymar   24
# ...       ...                 ...  ...
# 15280  231937         D. Williams   18
# 15148  227986        T. Ouldridge   17
# 17333  212270            M. Foden   20
# 17471  229429    K. McKenzie-Lyle   18
# 16832  238308           L. Sackey   17
#
#                                                   Photo Nationality  \
# 9      https://cdn.sofifa.com/players/020/801/17_60.png    Portugal
# 58     https://cdn.sofifa.com/players/158/023/17_60.png   Argentina
# 0      https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 12372  https://cdn.sofifa.com/players/167/495/17_60.png     Germany
# 168    https://cdn.sofifa.com/players/190/871/17_60.png      Brazil
# ...                                                 ...         ...
# ...

# %%
df.head()
# Out:
#        ID            Name  Age  \
# 0  176580       L. Suárez   29
# 1  178518   R. Nainggolan   28
# 2  181872        A. Vidal   29
# 3  197445        D. Alaba   24
# 4  195864        P. Pogba   23
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2  https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3  https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4  https://cdn.sofifa.com/players/195/864/17_60.png      France
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       92         92       FC Barcelona
# 1  https://cdn.sofifa.com/flags/be.png       86         86               Roma
# 2  https://cdn.sofifa.com/flags/cl.png       87         87  FC Bayern München
# ...

# %%
df
# Out:
#            ID            Name  Age  \
# 0      176580       L. Suárez   29
# 1      178518   R. Nainggolan   28
# 2      181872        A. Vidal   29
# 3      197445        D. Alaba   24
# 4      195864        P. Pogba   23
# ...       ...             ...  ...
# 17555  233215        C. Addai   18
# 17556  232911     R. Kamiyama   31
# 17557  235387         B. Gaye   18
# 17558  237904   K. Olifirenko   18
# 17559  237463       A. Kelsey   16
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1      https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2      https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3      https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4      https://cdn.sofifa.com/players/195/864/17_60.png      France
# ...                                                 ...         ...
# ...

# %%
player= df[0:5]
player
# Out:
#        ID            Name  Age  \
# 0  176580       L. Suárez   29
# 1  178518   R. Nainggolan   28
# 2  181872        A. Vidal   29
# 3  197445        D. Alaba   24
# 4  195864        P. Pogba   23
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2  https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3  https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4  https://cdn.sofifa.com/players/195/864/17_60.png      France
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       92         92       FC Barcelona
# 1  https://cdn.sofifa.com/flags/be.png       86         86               Roma
# 2  https://cdn.sofifa.com/flags/cl.png       87         87  FC Bayern München
# ...

# %%
ggplot(aes(x='Name'), player) + geom_bar(aes(y='Overall'), stat='identity')
